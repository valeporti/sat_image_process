# %%
import numpy as np
import glymur # a library to just open the images and treat them
                                                            
import matplotlib.pyplot as plt

# %%
jp2path = "../peps_download/S2A_OPER_PRD_MSIL1C_PDMC_20160715T112823_R051_V20151113T105818_20151113T105818.SAFE/GRANULE/S2A_OPER_MSI_L1C_TL_EPA__20160715T072356_A002050_T30TXP_N02.04/IMG_DATA/S2A_OPER_MSI_L1C_TL_EPA__20160715T072356_A002050_T30TXP_B02.jp2"
    
jp2 = glymur.Jp2k(jp2path)

# %%
image = jp2[:]

# %%
plt.imshow(image)
plt.show()
